# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import torch
from torch.utils.data import Dataset
from PIL import Image
import numpy as np
from google.colab import drive

class SPOTDataLoader(Dataset):
    def __init__(self, root_dir, labels_file, transform=None):
        print("Initializing SPOTDataLoader...")
        self.root_dir = root_dir
        self.transform = transform
        self.labels = np.load(labels_file)
        # print(f"Loaded labels from {labels_file} with shape: {self.labels.shape}")

        if torch.cuda.is_available():
            self.cuda = True
            # print("CUDA is available. Using GPU.")
        else:
            self.cuda = False
            # print("CUDA is not available. Using CPU.")

    def __len__(self):
        length = self.labels.shape[0]
        # print(f"Dataset length: {length}")
        return length

    def __getitem__(self, idx):
        # print(f"\nFetching data for index: {idx}")
        folder_name = format(idx, '05d')
        folder_path = os.path.join(self.root_dir, folder_name)
        # print(f"Constructed folder path: {folder_path}")

        input_images = []
        for i in range(4):
            input_image_path = os.path.join(folder_path, f"{i}.jpg")
            # print(f"Loading input image {i} from: {input_image_path}")
            image = Image.open(input_image_path).convert('RGB')
            # print(f"Loaded input image {i} with size: {image.size}")
            if self.transform:
                image = self.transform(image)
                #print(f"Applied transform to input image {i}.")
            input_images.append(image)

        goal_images = []
        for i in range(1):
            goal_image_path = os.path.join(folder_path, f"goal_{i}.jpg")
            # print(f"Loading goal image {i} from: {goal_image_path}")
            image = Image.open(goal_image_path).convert('RGB')
            # print(f"Loaded goal image {i} with size: {image.size}")
            if self.transform:
                image = self.transform(image)
                # print(f"Applied transform to goal image {i}.")
            goal_images.append(image)

        label = self.labels[idx]
        # print(f"Label for index {idx}: {label}")

        if self.cuda:
            input_images_tensor = torch.stack(input_images, dim=0).cuda()
            goal_images_tensor = torch.stack(goal_images, dim=0).cuda()
            label_tensor = torch.tensor(label).cuda()
            # print("Moved input images, goal images, and label tensor to GPU.")
        else:
            input_images_tensor = torch.stack(input_images, dim=0)
            goal_images_tensor = torch.stack(goal_images, dim=0)
            label_tensor = torch.tensor(label)
            # print("Using CPU tensors for input images, goal images, and label tensor.")

        # print(f"Input images tensor shape: {input_images_tensor.shape}")
        # print(f"Goal images tensor shape: {goal_images_tensor.shape}")
        # print(f"Label tensor: {label_tensor}")

        return input_images_tensor, goal_images_tensor, label_tensor

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision.models import resnet50

class CrossAttentionBlock(nn.Module):
    def __init__(self, embed_dim, num_heads=8):
        super(CrossAttentionBlock, self).__init__()
        self.mha = nn.MultiheadAttention(embed_dim, num_heads)

    def forward(self, query, key_value):
        # query and key_value: (B, C, H, W)
        B, C, H, W = query.shape

        # (H*W, B, C)
        query_flat = query.view(B, C, -1).permute(2, 0, 1)
        key_value_flat = key_value.view(B, C, -1).permute(2, 0, 1)

        attn_output, _ = self.mha(query_flat, key_value_flat, key_value_flat)

        # (B, C, H, W)
        attn_output = attn_output.permute(1, 2, 0).view(B, C, H, W)
        return attn_output

class SharedResNet50MLP(nn.Module):
    def __init__(self):
        super(SharedResNet50MLP, self).__init__()
        # === Using ResNet-50 trunk (excluding the last 2 layers: avgpool and fc) ===
        base_resnet = resnet50(weights=None)
        self.shared_trunk = nn.Sequential(*list(base_resnet.children())[:-2])

        self.global_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.num_cameras = 4

        # ResNet-50 outputs 2048 channels from the final convolution block
        num_trunk_channels = 2048

        # === Camera-specific heads for current images ===
        self.current_heads = nn.ModuleList([
            nn.Sequential(
                nn.Conv2d(num_trunk_channels, num_trunk_channels, kernel_size=1),
                nn.ReLU(inplace=True)
            ) for _ in range(self.num_cameras)
        ])

        # === Camera-specific heads for the goal image (each camera gets its own version) ===
        self.goal_heads = nn.ModuleList([
            nn.Sequential(
                nn.Conv2d(num_trunk_channels, num_trunk_channels, kernel_size=1),
                nn.ReLU(inplace=True)
            ) for _ in range(self.num_cameras)
        ])

        # === Cross-attention block shared across cameras ===
        self.cross_attention = CrossAttentionBlock(embed_dim=num_trunk_channels, num_heads=8)

        # === Fully connected layers ===
        #   Input feature dimension: (4 cameras * 2048) for current + (4 cameras * 2048) for goal = 16384
        self.fc_layer1 = nn.Sequential(
            nn.Linear(16384, 1024),
            nn.ReLU()
        )
        self.fc_layer2 = nn.Sequential(
            nn.Linear(1024, 1024),
            nn.ReLU()
        )
        self.fc_layer3 = nn.Sequential(
            nn.Linear(1024, 1024),
            nn.ReLU()
        )
        self.fc_layer4 = nn.Sequential(
            nn.Linear(1024, 1024),
            nn.ReLU()
        )
        # Final output layer (3 regression outputs)
        self.fc_layer5 = nn.Linear(1024, 3)

    def forward(self, current_images, goal_image):
        batch_size = current_images.size(0)
        current_features_list = []
        goal_features_list = []

        # === Processing the goal image once through the shared trunk ===
        goal_trunk_feat = self.shared_trunk(goal_image)  # (B, 2048, H', W')

        for cam_idx in range(self.num_cameras):
            # === Processing current image for camera cam_idx ===
            curr = current_images[:, cam_idx, :, :, :]   # (B, C, H, W)
            curr_feat = self.shared_trunk(curr)          # (B, 2048, H', W')
            curr_feat = self.current_heads[cam_idx](curr_feat)

            # === Processing goal image for this camera ===
            goal_feat = self.goal_heads[cam_idx](goal_trunk_feat)

            # === Applying cross-attention in both directions ===
            curr_attended = curr_feat + self.cross_attention(curr_feat, goal_feat)
            goal_attended = goal_feat + self.cross_attention(goal_feat, curr_feat)

            # === Global pooling ===
            curr_pooled = self.global_pool(curr_attended).view(batch_size, -1)  # (B, 2048)
            goal_pooled = self.global_pool(goal_attended).view(batch_size, -1)  # (B, 2048)

            current_features_list.append(curr_pooled)
            goal_features_list.append(goal_pooled)

        # === Concatenating features from all cameras ===
        current_features = torch.cat(current_features_list, dim=1)  # (B, 4*2048 = 8192)
        goal_features = torch.cat(goal_features_list, dim=1)        # (B, 8192)
        features = torch.cat([current_features, goal_features], dim=1)  # (B, 16384)

        # === Fully connected layers ===
        x = self.fc_layer1(features)
        x = self.fc_layer2(x)
        x = self.fc_layer3(x)
        x = self.fc_layer4(x)
        output = self.fc_layer5(x)  # (B, 3)

        return output

# %%
import matplotlib.pyplot as plt
import os

WEIGHT_SAVING_STEP = 10
DPI = 120
FIGURE_SIZE_PIXEL = [2490, 1490]
FIGURE_SIZE = [fsp / DPI for fsp in FIGURE_SIZE_PIXEL]

def plot_graph(training_losses, train_accuracies, figure_path=None, start_plot=0, end_plot=None):
    if end_plot is None or end_plot > len(training_losses):
        end_plot = len(training_losses)

    epochs = range(start_plot + 1, end_plot + 1)

    # ===== Training Loss =====
    plt.figure(figsize=FIGURE_SIZE, dpi=DPI)
    plt.scatter(epochs, training_losses[start_plot:end_plot], color='blue', label='Training Loss')
    plt.plot(epochs, training_losses[start_plot:end_plot], color='cyan', linestyle='-', label='Loss Trend')
    plt.title("Training Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss (scaled)")
    plt.legend()

    lowest_loss = min(training_losses[start_plot:end_plot])
    for i, loss in enumerate(training_losses[start_plot:end_plot], start=start_plot+1):
        if (i % WEIGHT_SAVING_STEP == 0) or (i == end_plot):
            plt.annotate(str(round(loss, 6)), xy=(i, loss))

    plt.text(0, plt.gca().get_ylim()[1], f'Lowest Loss: {lowest_loss:.6f}')

    if figure_path is not None:
        plt.savefig(os.path.join(figure_path, 'Training_loss.png'))
    plt.show()

    # ===== Training Accuracy =====
    plt.figure(figsize=FIGURE_SIZE, dpi=DPI)
    plt.plot(epochs, train_accuracies[start_plot:end_plot], color='green', linestyle='-', marker='o',
             label='Training Accuracy')
    plt.title("Training Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy (%)")
    plt.legend()

    for i, acc in enumerate(train_accuracies[start_plot:end_plot], start=start_plot+1):
        if (i % WEIGHT_SAVING_STEP == 0) or (i == end_plot):
            plt.annotate(f"{round(acc, 2)}", xy=(i, acc))

    if figure_path is not None:
        plt.savefig(os.path.join(figure_path, 'Training_accuracy.png'))
    plt.show()

# %%
import os
import torch
import numpy as np
from torch.utils.data import DataLoader
from torchvision import transforms

# === Paths ===
SPLIT_DATA_PATH = '/content/drive/MyDrive/Spot_IL/Real Test Data Lab'
LABEL_PATH = os.path.join(SPLIT_DATA_PATH, 'train/labels.npy')
TRAIN_PATH = os.path.join(SPLIT_DATA_PATH, 'train')

WEIGHT_PATH = os.path.join(SPLIT_DATA_PATH, 'weights/resnet50_mlp5_1e-4')
os.makedirs(WEIGHT_PATH, exist_ok=True)

FIGURE_PATH = os.path.join(SPLIT_DATA_PATH, 'Results/resnet50_mlp5_1e-4')
os.makedirs(FIGURE_PATH, exist_ok=True)

# === Data Transforms ===
data_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# === Device ===
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {DEVICE}')

# === Dataset (No Split) ===
full_dataset = SPOTDataLoader(
    root_dir=TRAIN_PATH,
    labels_file=LABEL_PATH,
    transform=data_transforms
)

# Using entire dataset for training
train_dataset = full_dataset
print(f'Training samples: {len(train_dataset)}')

BATCH_SIZE = 2
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

# === Hyperparameters & Loss ===
LEARNING_RATE = 1e-4
NUM_EPOCHS = 300
LOSS_SCALE = 1e3
TOLERANCE = 1e-1
loss_fn = torch.nn.MSELoss()

# === Model, Optimizer ===
model = SharedResNet50MLP().to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# === Training Loop ===
training_losses = []
train_accuracies = []

for epoch in range(1, NUM_EPOCHS + 1):
    # --- Training ---
    model.train()
    running_loss = 0.0
    for current_images, goal_images, labels in train_dataloader:
        goal_images = goal_images.squeeze(1)  # (B, 1, C, H, W) -> (B, C, H, W)
        current_images = current_images.to(DEVICE)
        goal_images = goal_images.to(DEVICE)
        labels = labels.to(DEVICE)

        optimizer.zero_grad()
        output = model(current_images, goal_images)  # (B, 3)
        loss = loss_fn(output, labels.float()) * LOSS_SCALE
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    epoch_loss = running_loss / len(train_dataloader)
    training_losses.append(epoch_loss)
    print(f"Epoch {epoch}/{NUM_EPOCHS} -- Training Loss: {epoch_loss:.6f}")

    # --- Training Accuracy ---
    model.eval()
    train_correct = 0
    train_total = 0
    with torch.no_grad():
        for current_images, goal_images, labels in train_dataloader:
            goal_images = goal_images.squeeze(1)
            current_images = current_images.to(DEVICE)
            goal_images = goal_images.to(DEVICE)
            labels = labels.to(DEVICE)

            output = model(current_images, goal_images)  # (B, 3)
            for i in range(output.size(0)):
                error = torch.norm(output[i] - labels[i].float(), p=2).item()
                train_total += 1
                if error < TOLERANCE:
                    train_correct += 1

    train_accuracy = (train_correct / train_total) * 100
    train_accuracies.append(train_accuracy)
    print(f"Epoch {epoch}/{NUM_EPOCHS} -- Training Accuracy: {train_accuracy:.2f}%")

    # --- Weights Every 10 Epochs ---
    if epoch % 10 == 0:
        weight_file = os.path.join(WEIGHT_PATH, f'epoch_{epoch}.pth')
        torch.save(model.state_dict(), weight_file)
        print(f"Weights saved at epoch {epoch}")

# === Final Model ===
final_weight_file = os.path.join(WEIGHT_PATH, f'final_epoch_{NUM_EPOCHS}.pth')
torch.save(model.state_dict(), final_weight_file)
print("Training complete. Final model saved.")
# Out:
# Using device: cuda
# Initializing SPOTDataLoader...
# Training samples: 15
# Epoch 1/300 -- Training Loss: 229.816933
# Epoch 1/300 -- Training Accuracy: 0.00%
# Epoch 2/300 -- Training Loss: 168.420343
# Epoch 2/300 -- Training Accuracy: 0.00%
# Epoch 3/300 -- Training Loss: 177.827114
# Epoch 3/300 -- Training Accuracy: 0.00%
# Epoch 4/300 -- Training Loss: 167.619052
# Epoch 4/300 -- Training Accuracy: 0.00%
# Epoch 5/300 -- Training Loss: 178.118664
# Epoch 5/300 -- Training Accuracy: 0.00%
# Epoch 6/300 -- Training Loss: 209.150288
# Epoch 6/300 -- Training Accuracy: 6.67%
# Epoch 7/300 -- Training Loss: 123.493973
# Epoch 7/300 -- Training Accuracy: 0.00%
# Epoch 8/300 -- Training Loss: 92.618121
# Epoch 8/300 -- Training Accuracy: 6.67%
# Epoch 9/300 -- Training Loss: 120.304899
# Epoch 9/300 -- Training Accuracy: 6.67%
# Epoch 10/300 -- Training Loss: 68.985400
# Epoch 10/300 -- Training Accuracy: 13.33%
# Weights saved at epoch 10
# Epoch 11/300 -- Training Loss: 75.060224
# Epoch 11/300 -- Training Accuracy: 6.67%
# Epoch 12/300 -- Training Loss: 58.198274
# Epoch 12/300 -- Training Accuracy: 13.33%
# Epoch 13/300 -- Training Loss: 71.165972
# Epoch 13/300 -- Training Accuracy: 20.00%
# Epoch 14/300 -- Training Loss: 49.704900
# Epoch 14/300 -- Training Accuracy: 20.00%
# Epoch 15/300 -- Training Loss: 87.382602
# Epoch 15/300 -- Training Accuracy: 13.33%
# Epoch 16/300 -- Training Loss: 47.076638
# Epoch 16/300 -- Training Accuracy: 20.00%
# Epoch 17/300 -- Training Loss: 60.712450
# Epoch 17/300 -- Training Accuracy: 26.67%
# Epoch 18/300 -- Training Loss: 48.873095
# Epoch 18/300 -- Training Accuracy: 13.33%
# Epoch 19/300 -- Training Loss: 50.628806
# Epoch 19/300 -- Training Accuracy: 6.67%
# Epoch 20/300 -- Training Loss: 49.772489
# Epoch 20/300 -- Training Accuracy: 13.33%
# Weights saved at epoch 20
# Epoch 21/300 -- Training Loss: 58.684562
# Epoch 21/300 -- Training Accuracy: 13.33%
# Epoch 22/300 -- Training Loss: 79.272158
# Epoch 22/300 -- Training Accuracy: 13.33%
# Epoch 23/300 -- Training Loss: 148.548705
# Epoch 23/300 -- Training Accuracy: 0.00%
# Epoch 24/300 -- Training Loss: 86.549083
# Epoch 24/300 -- Training Accuracy: 6.67%
# Epoch 25/300 -- Training Loss: 50.806404
# Epoch 25/300 -- Training Accuracy: 26.67%
# Epoch 26/300 -- Training Loss: 75.957922
# Epoch 26/300 -- Training Accuracy: 26.67%
# Epoch 27/300 -- Training Loss: 72.102092
# Epoch 27/300 -- Training Accuracy: 20.00%
# Epoch 28/300 -- Training Loss: 72.757657
# Epoch 28/300 -- Training Accuracy: 6.67%
# Epoch 29/300 -- Training Loss: 51.985952
# Epoch 29/300 -- Training Accuracy: 26.67%
# Epoch 30/300 -- Training Loss: 94.743851
# Epoch 30/300 -- Training Accuracy: 6.67%
# Weights saved at epoch 30
# Epoch 31/300 -- Training Loss: 79.155362
# Epoch 31/300 -- Training Accuracy: 6.67%
# Epoch 32/300 -- Training Loss: 90.180519
# Epoch 32/300 -- Training Accuracy: 6.67%
# Epoch 33/300 -- Training Loss: 72.752850
# Epoch 33/300 -- Training Accuracy: 6.67%
# Epoch 34/300 -- Training Loss: 100.057504
# Epoch 34/300 -- Training Accuracy: 13.33%
# Epoch 35/300 -- Training Loss: 49.806394
# Epoch 35/300 -- Training Accuracy: 20.00%
# Epoch 36/300 -- Training Loss: 38.064756
# Epoch 36/300 -- Training Accuracy: 20.00%
# Epoch 37/300 -- Training Loss: 38.400542
# Epoch 37/300 -- Training Accuracy: 26.67%
# Epoch 38/300 -- Training Loss: 44.720706
# Epoch 38/300 -- Training Accuracy: 26.67%
# Epoch 39/300 -- Training Loss: 35.178514
# Epoch 39/300 -- Training Accuracy: 26.67%
# Epoch 40/300 -- Training Loss: 57.414873
# Epoch 40/300 -- Training Accuracy: 13.33%
# Weights saved at epoch 40
# Epoch 41/300 -- Training Loss: 67.088696
# Epoch 41/300 -- Training Accuracy: 13.33%
# Epoch 42/300 -- Training Loss: 65.046973
# Epoch 42/300 -- Training Accuracy: 13.33%
# Epoch 43/300 -- Training Loss: 61.738103
# Epoch 43/300 -- Training Accuracy: 20.00%
# Epoch 44/300 -- Training Loss: 37.789643
# Epoch 44/300 -- Training Accuracy: 13.33%
# Epoch 45/300 -- Training Loss: 69.637165
# Epoch 45/300 -- Training Accuracy: 13.33%
# Epoch 46/300 -- Training Loss: 100.845495
# Epoch 46/300 -- Training Accuracy: 6.67%
# Epoch 47/300 -- Training Loss: 84.817409
# Epoch 47/300 -- Training Accuracy: 33.33%
# Epoch 48/300 -- Training Loss: 58.403796
# Epoch 48/300 -- Training Accuracy: 33.33%
# Epoch 49/300 -- Training Loss: 80.728481
# Epoch 49/300 -- Training Accuracy: 13.33%
# Epoch 50/300 -- Training Loss: 172.192869
# Epoch 50/300 -- Training Accuracy: 26.67%
# Weights saved at epoch 50
# Epoch 51/300 -- Training Loss: 79.636078
# Epoch 51/300 -- Training Accuracy: 6.67%
# Epoch 52/300 -- Training Loss: 68.294164
# Epoch 52/300 -- Training Accuracy: 0.00%
# Epoch 53/300 -- Training Loss: 61.991112
# Epoch 53/300 -- Training Accuracy: 6.67%
# Epoch 54/300 -- Training Loss: 56.197204
# Epoch 54/300 -- Training Accuracy: 6.67%
# Epoch 55/300 -- Training Loss: 44.809511
# Epoch 55/300 -- Training Accuracy: 20.00%
# Epoch 56/300 -- Training Loss: 85.937385
# Epoch 56/300 -- Training Accuracy: 33.33%
# Epoch 57/300 -- Training Loss: 64.360253
# Epoch 57/300 -- Training Accuracy: 20.00%
# Epoch 58/300 -- Training Loss: 77.277160
# Epoch 58/300 -- Training Accuracy: 13.33%
# Epoch 59/300 -- Training Loss: 45.708838
# Epoch 59/300 -- Training Accuracy: 26.67%
# Epoch 60/300 -- Training Loss: 89.190025
# Epoch 60/300 -- Training Accuracy: 20.00%
# Weights saved at epoch 60
# Epoch 61/300 -- Training Loss: 44.667328
# Epoch 61/300 -- Training Accuracy: 13.33%
# Epoch 62/300 -- Training Loss: 43.090502
# Epoch 62/300 -- Training Accuracy: 20.00%
# Epoch 63/300 -- Training Loss: 41.052540
# Epoch 63/300 -- Training Accuracy: 13.33%
# Epoch 64/300 -- Training Loss: 28.566342
# Epoch 64/300 -- Training Accuracy: 13.33%
# Epoch 65/300 -- Training Loss: 25.071550
# Epoch 65/300 -- Training Accuracy: 20.00%
# Epoch 66/300 -- Training Loss: 27.156270
# Epoch 66/300 -- Training Accuracy: 26.67%
# Epoch 67/300 -- Training Loss: 14.788183
# Epoch 67/300 -- Training Accuracy: 13.33%
# Epoch 68/300 -- Training Loss: 24.163592
# Epoch 68/300 -- Training Accuracy: 26.67%
# Epoch 69/300 -- Training Loss: 29.645510
# Epoch 69/300 -- Training Accuracy: 20.00%
# Epoch 70/300 -- Training Loss: 25.225912
# Epoch 70/300 -- Training Accuracy: 26.67%
# Weights saved at epoch 70
# Epoch 71/300 -- Training Loss: 17.061249
# Epoch 71/300 -- Training Accuracy: 0.00%
# Epoch 72/300 -- Training Loss: 61.000916
# Epoch 72/300 -- Training Accuracy: 20.00%
# Epoch 73/300 -- Training Loss: 31.398130
# Epoch 73/300 -- Training Accuracy: 20.00%
# Epoch 74/300 -- Training Loss: 30.777381
# Epoch 74/300 -- Training Accuracy: 6.67%
# Epoch 75/300 -- Training Loss: 31.973150
# Epoch 75/300 -- Training Accuracy: 13.33%
# Epoch 76/300 -- Training Loss: 21.010203
# Epoch 76/300 -- Training Accuracy: 20.00%
# Epoch 77/300 -- Training Loss: 35.503702
# Epoch 77/300 -- Training Accuracy: 6.67%
# Epoch 78/300 -- Training Loss: 27.898463
# Epoch 78/300 -- Training Accuracy: 13.33%
# Epoch 79/300 -- Training Loss: 28.397424
# Epoch 79/300 -- Training Accuracy: 6.67%
# Epoch 80/300 -- Training Loss: 63.682678
# Epoch 80/300 -- Training Accuracy: 6.67%
# Weights saved at epoch 80
# Epoch 81/300 -- Training Loss: 20.819332
# Epoch 81/300 -- Training Accuracy: 26.67%
# Epoch 82/300 -- Training Loss: 26.492270
# Epoch 82/300 -- Training Accuracy: 26.67%
# Epoch 83/300 -- Training Loss: 25.525276
# Epoch 83/300 -- Training Accuracy: 26.67%
# Epoch 84/300 -- Training Loss: 17.826436
# Epoch 84/300 -- Training Accuracy: 26.67%
# Epoch 85/300 -- Training Loss: 12.674854
# Epoch 85/300 -- Training Accuracy: 6.67%
# Epoch 86/300 -- Training Loss: 11.927274
# Epoch 86/300 -- Training Accuracy: 0.00%
# Epoch 87/300 -- Training Loss: 20.731145
# Epoch 87/300 -- Training Accuracy: 33.33%
# Epoch 88/300 -- Training Loss: 14.789553
# Epoch 88/300 -- Training Accuracy: 26.67%
# Epoch 89/300 -- Training Loss: 19.723790
# Epoch 89/300 -- Training Accuracy: 33.33%
# Epoch 90/300 -- Training Loss: 12.817140
# Epoch 90/300 -- Training Accuracy: 6.67%
# Weights saved at epoch 90
# Epoch 91/300 -- Training Loss: 22.508872
# Epoch 91/300 -- Training Accuracy: 40.00%
# Epoch 92/300 -- Training Loss: 9.634140
# Epoch 92/300 -- Training Accuracy: 33.33%
# Epoch 93/300 -- Training Loss: 9.412457
# Epoch 93/300 -- Training Accuracy: 33.33%
# Epoch 94/300 -- Training Loss: 9.628368
# Epoch 94/300 -- Training Accuracy: 6.67%
# Epoch 95/300 -- Training Loss: 7.047664
# Epoch 95/300 -- Training Accuracy: 13.33%
# Epoch 96/300 -- Training Loss: 8.337182
# Epoch 96/300 -- Training Accuracy: 33.33%
# Epoch 97/300 -- Training Loss: 23.093052
# Epoch 97/300 -- Training Accuracy: 20.00%
# Epoch 98/300 -- Training Loss: 7.009000
# Epoch 98/300 -- Training Accuracy: 26.67%
# Epoch 99/300 -- Training Loss: 11.584917
# Epoch 99/300 -- Training Accuracy: 20.00%
# Epoch 100/300 -- Training Loss: 6.125958
# Epoch 100/300 -- Training Accuracy: 33.33%
# Weights saved at epoch 100
# Epoch 101/300 -- Training Loss: 6.820214
# Epoch 101/300 -- Training Accuracy: 33.33%
# Epoch 102/300 -- Training Loss: 5.868360
# Epoch 102/300 -- Training Accuracy: 26.67%
# Epoch 103/300 -- Training Loss: 6.022174
# Epoch 103/300 -- Training Accuracy: 33.33%
# Epoch 104/300 -- Training Loss: 6.497288
# Epoch 104/300 -- Training Accuracy: 33.33%
# Epoch 105/300 -- Training Loss: 5.646121
# Epoch 105/300 -- Training Accuracy: 33.33%
# Epoch 106/300 -- Training Loss: 3.282803
# Epoch 106/300 -- Training Accuracy: 46.67%
# Epoch 107/300 -- Training Loss: 4.573568
# Epoch 107/300 -- Training Accuracy: 33.33%
# Epoch 108/300 -- Training Loss: 2.820892
# Epoch 108/300 -- Training Accuracy: 40.00%
# Epoch 109/300 -- Training Loss: 4.761655
# Epoch 109/300 -- Training Accuracy: 46.67%
# Epoch 110/300 -- Training Loss: 7.111065
# Epoch 110/300 -- Training Accuracy: 26.67%
# Weights saved at epoch 110
# Epoch 111/300 -- Training Loss: 8.039443
# Epoch 111/300 -- Training Accuracy: 46.67%
# Epoch 112/300 -- Training Loss: 4.583118
# Epoch 112/300 -- Training Accuracy: 40.00%
# Epoch 113/300 -- Training Loss: 6.613549
# Epoch 113/300 -- Training Accuracy: 53.33%
# Epoch 114/300 -- Training Loss: 7.471838
# Epoch 114/300 -- Training Accuracy: 40.00%
# Epoch 115/300 -- Training Loss: 14.315818
# Epoch 115/300 -- Training Accuracy: 20.00%
# Epoch 116/300 -- Training Loss: 6.708354
# Epoch 116/300 -- Training Accuracy: 40.00%
# Epoch 117/300 -- Training Loss: 6.285861
# Epoch 117/300 -- Training Accuracy: 26.67%
# Epoch 118/300 -- Training Loss: 8.419934
# Epoch 118/300 -- Training Accuracy: 26.67%
# Epoch 119/300 -- Training Loss: 5.929029
# Epoch 119/300 -- Training Accuracy: 40.00%
# Epoch 120/300 -- Training Loss: 4.145875
# Epoch 120/300 -- Training Accuracy: 40.00%
# Weights saved at epoch 120
# Epoch 121/300 -- Training Loss: 4.867745
# Epoch 121/300 -- Training Accuracy: 33.33%
# Epoch 122/300 -- Training Loss: 8.351114
# Epoch 122/300 -- Training Accuracy: 33.33%
# Epoch 123/300 -- Training Loss: 14.385508
# Epoch 123/300 -- Training Accuracy: 40.00%
# Epoch 124/300 -- Training Loss: 6.206959
# Epoch 124/300 -- Training Accuracy: 40.00%
# Epoch 125/300 -- Training Loss: 4.011808
# Epoch 125/300 -- Training Accuracy: 46.67%
# Epoch 126/300 -- Training Loss: 5.256776
# Epoch 126/300 -- Training Accuracy: 26.67%
# Epoch 127/300 -- Training Loss: 2.510426
# Epoch 127/300 -- Training Accuracy: 40.00%
# Epoch 128/300 -- Training Loss: 2.200319
# Epoch 128/300 -- Training Accuracy: 40.00%
# Epoch 129/300 -- Training Loss: 1.979189
# Epoch 129/300 -- Training Accuracy: 40.00%
# Epoch 130/300 -- Training Loss: 1.908911
# Epoch 130/300 -- Training Accuracy: 40.00%
# Weights saved at epoch 130
# Epoch 131/300 -- Training Loss: 4.142276
# Epoch 131/300 -- Training Accuracy: 46.67%
# Epoch 132/300 -- Training Loss: 8.585755
# Epoch 132/300 -- Training Accuracy: 46.67%
# Epoch 133/300 -- Training Loss: 10.729218
# Epoch 133/300 -- Training Accuracy: 26.67%
# Epoch 134/300 -- Training Loss: 21.372743
# Epoch 134/300 -- Training Accuracy: 46.67%
# Epoch 135/300 -- Training Loss: 12.265218
# Epoch 135/300 -- Training Accuracy: 33.33%
# Epoch 136/300 -- Training Loss: 25.557095
# Epoch 136/300 -- Training Accuracy: 33.33%
# Epoch 137/300 -- Training Loss: 17.847379
# Epoch 137/300 -- Training Accuracy: 40.00%
# Epoch 138/300 -- Training Loss: 7.538204
# Epoch 138/300 -- Training Accuracy: 40.00%
# Epoch 139/300 -- Training Loss: 14.099814
# Epoch 139/300 -- Training Accuracy: 26.67%
# Epoch 140/300 -- Training Loss: 15.576514
# Epoch 140/300 -- Training Accuracy: 13.33%
# Weights saved at epoch 140
# Epoch 141/300 -- Training Loss: 7.370240
# Epoch 141/300 -- Training Accuracy: 40.00%
# Epoch 142/300 -- Training Loss: 10.281957
# Epoch 142/300 -- Training Accuracy: 40.00%
# Epoch 143/300 -- Training Loss: 8.975270
# Epoch 143/300 -- Training Accuracy: 33.33%
# Epoch 144/300 -- Training Loss: 7.438925
# Epoch 144/300 -- Training Accuracy: 40.00%
# Epoch 145/300 -- Training Loss: 13.719801
# Epoch 145/300 -- Training Accuracy: 33.33%
# Epoch 146/300 -- Training Loss: 17.844669
# Epoch 146/300 -- Training Accuracy: 26.67%
# Epoch 147/300 -- Training Loss: 4.788702
# Epoch 147/300 -- Training Accuracy: 40.00%
# Epoch 148/300 -- Training Loss: 6.423701
# Epoch 148/300 -- Training Accuracy: 33.33%
# Epoch 149/300 -- Training Loss: 5.513617
# Epoch 149/300 -- Training Accuracy: 6.67%
# Epoch 150/300 -- Training Loss: 7.044066
# Epoch 150/300 -- Training Accuracy: 13.33%
# Weights saved at epoch 150
# Epoch 151/300 -- Training Loss: 4.364495
# Epoch 151/300 -- Training Accuracy: 33.33%
# Epoch 152/300 -- Training Loss: 8.891657
# Epoch 152/300 -- Training Accuracy: 13.33%
# Epoch 153/300 -- Training Loss: 4.783701
# Epoch 153/300 -- Training Accuracy: 26.67%
# Epoch 154/300 -- Training Loss: 3.925861
# Epoch 154/300 -- Training Accuracy: 26.67%
# Epoch 155/300 -- Training Loss: 4.568701
# Epoch 155/300 -- Training Accuracy: 33.33%
# Epoch 156/300 -- Training Loss: 7.033018
# Epoch 156/300 -- Training Accuracy: 6.67%
# Epoch 157/300 -- Training Loss: 7.240340
# Epoch 157/300 -- Training Accuracy: 40.00%
# Epoch 158/300 -- Training Loss: 3.505836
# Epoch 158/300 -- Training Accuracy: 33.33%
# Epoch 159/300 -- Training Loss: 3.375369
# Epoch 159/300 -- Training Accuracy: 33.33%
# Epoch 160/300 -- Training Loss: 2.611154
# Epoch 160/300 -- Training Accuracy: 33.33%
# Weights saved at epoch 160
# Epoch 161/300 -- Training Loss: 4.883374
# Epoch 161/300 -- Training Accuracy: 40.00%
# Epoch 162/300 -- Training Loss: 3.512932
# Epoch 162/300 -- Training Accuracy: 26.67%
# Epoch 163/300 -- Training Loss: 3.139093
# Epoch 163/300 -- Training Accuracy: 33.33%
# Epoch 164/300 -- Training Loss: 2.336200
# Epoch 164/300 -- Training Accuracy: 53.33%
# Epoch 165/300 -- Training Loss: 2.396731
# Epoch 165/300 -- Training Accuracy: 13.33%
# Epoch 166/300 -- Training Loss: 15.640958
# Epoch 166/300 -- Training Accuracy: 53.33%
# Epoch 167/300 -- Training Loss: 5.256924
# Epoch 167/300 -- Training Accuracy: 20.00%
# Epoch 168/300 -- Training Loss: 5.234305
# Epoch 168/300 -- Training Accuracy: 33.33%
# Epoch 169/300 -- Training Loss: 4.132423
# Epoch 169/300 -- Training Accuracy: 46.67%
# Epoch 170/300 -- Training Loss: 9.600686
# Epoch 170/300 -- Training Accuracy: 6.67%
# Weights saved at epoch 170
# Epoch 171/300 -- Training Loss: 11.102464
# Epoch 171/300 -- Training Accuracy: 40.00%
# Epoch 172/300 -- Training Loss: 19.001053
# Epoch 172/300 -- Training Accuracy: 33.33%
# Epoch 173/300 -- Training Loss: 14.600804
# Epoch 173/300 -- Training Accuracy: 40.00%
# Epoch 174/300 -- Training Loss: 13.692090
# Epoch 174/300 -- Training Accuracy: 26.67%
# Epoch 175/300 -- Training Loss: 25.443782
# Epoch 175/300 -- Training Accuracy: 33.33%
# Epoch 176/300 -- Training Loss: 45.479095
# Epoch 176/300 -- Training Accuracy: 6.67%
# Epoch 177/300 -- Training Loss: 35.535868
# Epoch 177/300 -- Training Accuracy: 33.33%
# Epoch 178/300 -- Training Loss: 17.144865
# Epoch 178/300 -- Training Accuracy: 33.33%
# Epoch 179/300 -- Training Loss: 15.918450
# Epoch 179/300 -- Training Accuracy: 13.33%
# Epoch 180/300 -- Training Loss: 15.283027
# Epoch 180/300 -- Training Accuracy: 0.00%
# Weights saved at epoch 180
# Epoch 181/300 -- Training Loss: 13.180185
# Epoch 181/300 -- Training Accuracy: 33.33%
# Epoch 182/300 -- Training Loss: 8.158282
# Epoch 182/300 -- Training Accuracy: 33.33%
# Epoch 183/300 -- Training Loss: 11.487697
# Epoch 183/300 -- Training Accuracy: 33.33%
# Epoch 184/300 -- Training Loss: 13.435894
# Epoch 184/300 -- Training Accuracy: 40.00%
# Epoch 185/300 -- Training Loss: 6.342912
# Epoch 185/300 -- Training Accuracy: 20.00%
# Epoch 186/300 -- Training Loss: 11.883908
# Epoch 186/300 -- Training Accuracy: 40.00%
# Epoch 187/300 -- Training Loss: 16.138003
# Epoch 187/300 -- Training Accuracy: 26.67%
# Epoch 188/300 -- Training Loss: 16.637142
# Epoch 188/300 -- Training Accuracy: 13.33%
# Epoch 189/300 -- Training Loss: 20.318545
# Epoch 189/300 -- Training Accuracy: 33.33%
# Epoch 190/300 -- Training Loss: 15.595642
# Epoch 190/300 -- Training Accuracy: 40.00%
# Weights saved at epoch 190
# Epoch 191/300 -- Training Loss: 10.411607
# Epoch 191/300 -- Training Accuracy: 26.67%
# Epoch 192/300 -- Training Loss: 8.432847
# Epoch 192/300 -- Training Accuracy: 26.67%
# Epoch 193/300 -- Training Loss: 5.533182
# Epoch 193/300 -- Training Accuracy: 20.00%
# Epoch 194/300 -- Training Loss: 6.700698
# Epoch 194/300 -- Training Accuracy: 46.67%
# Epoch 195/300 -- Training Loss: 3.179709
# Epoch 195/300 -- Training Accuracy: 20.00%
# Epoch 196/300 -- Training Loss: 4.272255
# Epoch 196/300 -- Training Accuracy: 26.67%
# Epoch 197/300 -- Training Loss: 1.733257
# Epoch 197/300 -- Training Accuracy: 20.00%
# Epoch 198/300 -- Training Loss: 2.013482
# Epoch 198/300 -- Training Accuracy: 20.00%
# Epoch 199/300 -- Training Loss: 3.641204
# Epoch 199/300 -- Training Accuracy: 40.00%
# Epoch 200/300 -- Training Loss: 1.645978
# Epoch 200/300 -- Training Accuracy: 40.00%
# Weights saved at epoch 200
# Epoch 201/300 -- Training Loss: 1.260970
# Epoch 201/300 -- Training Accuracy: 33.33%
# Epoch 202/300 -- Training Loss: 1.050580
# Epoch 202/300 -- Training Accuracy: 26.67%
# Epoch 203/300 -- Training Loss: 1.320963
# Epoch 203/300 -- Training Accuracy: 53.33%
# Epoch 204/300 -- Training Loss: 1.141472
# Epoch 204/300 -- Training Accuracy: 40.00%
# Epoch 205/300 -- Training Loss: 1.826836
# Epoch 205/300 -- Training Accuracy: 26.67%
# Epoch 206/300 -- Training Loss: 2.857081
# Epoch 206/300 -- Training Accuracy: 33.33%
# Epoch 207/300 -- Training Loss: 1.525046
# Epoch 207/300 -- Training Accuracy: 40.00%
# Epoch 208/300 -- Training Loss: 2.011549
# Epoch 208/300 -- Training Accuracy: 33.33%
# Epoch 209/300 -- Training Loss: 2.943317
# Epoch 209/300 -- Training Accuracy: 26.67%
# Epoch 210/300 -- Training Loss: 2.850306
# Epoch 210/300 -- Training Accuracy: 26.67%
# Weights saved at epoch 210
# Epoch 211/300 -- Training Loss: 2.260225
# Epoch 211/300 -- Training Accuracy: 40.00%
# Epoch 212/300 -- Training Loss: 1.364080
# Epoch 212/300 -- Training Accuracy: 33.33%
# Epoch 213/300 -- Training Loss: 0.869044
# Epoch 213/300 -- Training Accuracy: 20.00%
# Epoch 214/300 -- Training Loss: 1.013147
# Epoch 214/300 -- Training Accuracy: 26.67%
# Epoch 215/300 -- Training Loss: 0.658982
# Epoch 215/300 -- Training Accuracy: 40.00%
# Epoch 216/300 -- Training Loss: 0.602420
# Epoch 216/300 -- Training Accuracy: 33.33%
# Epoch 217/300 -- Training Loss: 1.258102
# Epoch 217/300 -- Training Accuracy: 46.67%
# Epoch 218/300 -- Training Loss: 0.797985
# Epoch 218/300 -- Training Accuracy: 33.33%
# Epoch 219/300 -- Training Loss: 0.750332
# Epoch 219/300 -- Training Accuracy: 46.67%
# Epoch 220/300 -- Training Loss: 0.715062
# Epoch 220/300 -- Training Accuracy: 53.33%
# Weights saved at epoch 220
# Epoch 221/300 -- Training Loss: 1.352607
# Epoch 221/300 -- Training Accuracy: 26.67%
# Epoch 222/300 -- Training Loss: 3.004292
# Epoch 222/300 -- Training Accuracy: 33.33%
# Epoch 223/300 -- Training Loss: 2.035272
# Epoch 223/300 -- Training Accuracy: 40.00%
# Epoch 224/300 -- Training Loss: 1.884054
# Epoch 224/300 -- Training Accuracy: 26.67%
# Epoch 225/300 -- Training Loss: 1.060846
# Epoch 225/300 -- Training Accuracy: 26.67%
# Epoch 226/300 -- Training Loss: 1.145879
# Epoch 226/300 -- Training Accuracy: 33.33%
# Epoch 227/300 -- Training Loss: 1.859766
# Epoch 227/300 -- Training Accuracy: 26.67%
# Epoch 228/300 -- Training Loss: 0.934683
# Epoch 228/300 -- Training Accuracy: 26.67%
# Epoch 229/300 -- Training Loss: 0.668450
# Epoch 229/300 -- Training Accuracy: 26.67%
# Epoch 230/300 -- Training Loss: 0.700364
# Epoch 230/300 -- Training Accuracy: 46.67%
# Weights saved at epoch 230
# Epoch 231/300 -- Training Loss: 0.627785
# Epoch 231/300 -- Training Accuracy: 33.33%
# Epoch 232/300 -- Training Loss: 0.692821
# Epoch 232/300 -- Training Accuracy: 46.67%
# Epoch 233/300 -- Training Loss: 0.680127
# Epoch 233/300 -- Training Accuracy: 33.33%
# Epoch 234/300 -- Training Loss: 0.545733
# Epoch 234/300 -- Training Accuracy: 40.00%
# Epoch 235/300 -- Training Loss: 0.916885
# Epoch 235/300 -- Training Accuracy: 40.00%
# Epoch 236/300 -- Training Loss: 0.931001
# Epoch 236/300 -- Training Accuracy: 46.67%
# Epoch 237/300 -- Training Loss: 1.642090
# Epoch 237/300 -- Training Accuracy: 20.00%
# Epoch 238/300 -- Training Loss: 2.312591
# Epoch 238/300 -- Training Accuracy: 53.33%
# Epoch 239/300 -- Training Loss: 1.676204
# Epoch 239/300 -- Training Accuracy: 40.00%
# Epoch 240/300 -- Training Loss: 2.224740
# Epoch 240/300 -- Training Accuracy: 60.00%
# Weights saved at epoch 240
# Epoch 241/300 -- Training Loss: 1.541780
# Epoch 241/300 -- Training Accuracy: 26.67%
# Epoch 242/300 -- Training Loss: 3.055361
# Epoch 242/300 -- Training Accuracy: 53.33%
# Epoch 243/300 -- Training Loss: 4.071200
# Epoch 243/300 -- Training Accuracy: 40.00%
# Epoch 244/300 -- Training Loss: 2.984351
# Epoch 244/300 -- Training Accuracy: 40.00%
# Epoch 245/300 -- Training Loss: 3.185323
# Epoch 245/300 -- Training Accuracy: 46.67%
# Epoch 246/300 -- Training Loss: 2.018409
# Epoch 246/300 -- Training Accuracy: 40.00%
# Epoch 247/300 -- Training Loss: 1.698056
# Epoch 247/300 -- Training Accuracy: 33.33%
# Epoch 248/300 -- Training Loss: 1.133447
# Epoch 248/300 -- Training Accuracy: 53.33%
# Epoch 249/300 -- Training Loss: 1.120811
# Epoch 249/300 -- Training Accuracy: 40.00%
# Epoch 250/300 -- Training Loss: 1.364759
# Epoch 250/300 -- Training Accuracy: 60.00%
# Weights saved at epoch 250
# Epoch 251/300 -- Training Loss: 0.979879
# Epoch 251/300 -- Training Accuracy: 33.33%
# Epoch 252/300 -- Training Loss: 1.649963
# Epoch 252/300 -- Training Accuracy: 53.33%
# Epoch 253/300 -- Training Loss: 1.411278
# Epoch 253/300 -- Training Accuracy: 46.67%
# Epoch 254/300 -- Training Loss: 3.096259
# Epoch 254/300 -- Training Accuracy: 53.33%
# Epoch 255/300 -- Training Loss: 6.474730
# Epoch 255/300 -- Training Accuracy: 40.00%
# Epoch 256/300 -- Training Loss: 2.309657
# Epoch 256/300 -- Training Accuracy: 66.67%
# Epoch 257/300 -- Training Loss: 1.736343
# Epoch 257/300 -- Training Accuracy: 26.67%
# Epoch 258/300 -- Training Loss: 1.140570
# Epoch 258/300 -- Training Accuracy: 40.00%
# Epoch 259/300 -- Training Loss: 0.947248
# Epoch 259/300 -- Training Accuracy: 53.33%
# Epoch 260/300 -- Training Loss: 2.330263
# Epoch 260/300 -- Training Accuracy: 40.00%
# Weights saved at epoch 260
# Epoch 261/300 -- Training Loss: 1.118666
# Epoch 261/300 -- Training Accuracy: 60.00%
# Epoch 262/300 -- Training Loss: 0.555837
# Epoch 262/300 -- Training Accuracy: 53.33%
# Epoch 263/300 -- Training Loss: 0.446625
# Epoch 263/300 -- Training Accuracy: 53.33%
# Epoch 264/300 -- Training Loss: 0.391696
# Epoch 264/300 -- Training Accuracy: 46.67%
# Epoch 265/300 -- Training Loss: 0.303466
# Epoch 265/300 -- Training Accuracy: 53.33%
# Epoch 266/300 -- Training Loss: 0.271197
# Epoch 266/300 -- Training Accuracy: 40.00%
# Epoch 267/300 -- Training Loss: 0.351571
# Epoch 267/300 -- Training Accuracy: 46.67%
# Epoch 268/300 -- Training Loss: 0.716420
# Epoch 268/300 -- Training Accuracy: 46.67%
# Epoch 269/300 -- Training Loss: 0.653082
# Epoch 269/300 -- Training Accuracy: 46.67%
# Epoch 270/300 -- Training Loss: 2.363714
# Epoch 270/300 -- Training Accuracy: 53.33%
# Weights saved at epoch 270
# Epoch 271/300 -- Training Loss: 0.890524
# Epoch 271/300 -- Training Accuracy: 46.67%
# Epoch 272/300 -- Training Loss: 3.547295
# Epoch 272/300 -- Training Accuracy: 40.00%
# Epoch 273/300 -- Training Loss: 3.887866
# Epoch 273/300 -- Training Accuracy: 53.33%
# Epoch 274/300 -- Training Loss: 4.268724
# Epoch 274/300 -- Training Accuracy: 60.00%
# Epoch 275/300 -- Training Loss: 3.213041
# Epoch 275/300 -- Training Accuracy: 26.67%
# Epoch 276/300 -- Training Loss: 2.439410
# Epoch 276/300 -- Training Accuracy: 80.00%
# Epoch 277/300 -- Training Loss: 1.720473
# Epoch 277/300 -- Training Accuracy: 40.00%
# Epoch 278/300 -- Training Loss: 2.541301
# Epoch 278/300 -- Training Accuracy: 73.33%
# Epoch 279/300 -- Training Loss: 1.726987
# Epoch 279/300 -- Training Accuracy: 33.33%
# Epoch 280/300 -- Training Loss: 2.319052
# Epoch 280/300 -- Training Accuracy: 73.33%
# Weights saved at epoch 280
# Epoch 281/300 -- Training Loss: 1.704362
# Epoch 281/300 -- Training Accuracy: 80.00%
# Epoch 282/300 -- Training Loss: 1.064483
# Epoch 282/300 -- Training Accuracy: 40.00%
# Epoch 283/300 -- Training Loss: 0.981694
# Epoch 283/300 -- Training Accuracy: 73.33%
# Epoch 284/300 -- Training Loss: 0.488642
# Epoch 284/300 -- Training Accuracy: 46.67%
# Epoch 285/300 -- Training Loss: 1.555039
# Epoch 285/300 -- Training Accuracy: 60.00%
# Epoch 286/300 -- Training Loss: 4.291312
# Epoch 286/300 -- Training Accuracy: 73.33%
# Epoch 287/300 -- Training Loss: 4.197337
# Epoch 287/300 -- Training Accuracy: 33.33%
# Epoch 288/300 -- Training Loss: 5.292453
# Epoch 288/300 -- Training Accuracy: 53.33%
# Epoch 289/300 -- Training Loss: 4.131208
# Epoch 289/300 -- Training Accuracy: 40.00%
# Epoch 290/300 -- Training Loss: 4.564306
# Epoch 290/300 -- Training Accuracy: 73.33%
# Weights saved at epoch 290
# Epoch 291/300 -- Training Loss: 4.736250
# Epoch 291/300 -- Training Accuracy: 33.33%
# Epoch 292/300 -- Training Loss: 3.260631
# Epoch 292/300 -- Training Accuracy: 66.67%
# Epoch 293/300 -- Training Loss: 3.100707
# Epoch 293/300 -- Training Accuracy: 46.67%
# Epoch 294/300 -- Training Loss: 2.424759
# Epoch 294/300 -- Training Accuracy: 46.67%
# Epoch 295/300 -- Training Loss: 2.462928
# Epoch 295/300 -- Training Accuracy: 60.00%
# Epoch 296/300 -- Training Loss: 3.186951
# Epoch 296/300 -- Training Accuracy: 40.00%
# Epoch 297/300 -- Training Loss: 1.675963
# Epoch 297/300 -- Training Accuracy: 46.67%
# Epoch 298/300 -- Training Loss: 1.089386
# Epoch 298/300 -- Training Accuracy: 40.00%
# Epoch 299/300 -- Training Loss: 1.044331
# Epoch 299/300 -- Training Accuracy: 40.00%
# Epoch 300/300 -- Training Loss: 0.635311
# Epoch 300/300 -- Training Accuracy: 53.33%
# Weights saved at epoch 300
# Training complete. Final model saved.

# %%
# === Plot Training Curves (Optional) ===
# If your plot_graph function expects validation accuracies, remove or adapt that argument:
plot_graph(training_losses, train_accuracies, FIGURE_PATH, start_plot=0, end_plot=NUM_EPOCHS)
